# %% [markdown]
# ### This is using FastAI v1 codebase

# %%
from fastai.text import *
import pandas as pd
import numpy as np

# %% [markdown]
# ### Install sklearn package separately, if necessary

# %%
# Uncomment below if you need to install sklearn
# !pip install sklearn

from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Begin reading in and prepping data

# %%
#PATH = "~/Desktop/magellan-ai/bullwinkle/data/has_ads/"
PATH = "storage/sample/"

df_trn = pd.read_csv(f'{PATH}training_sample.csv')

df_tst = pd.read_csv(f'{PATH}holdout_for_Sampling_test.csv')
df_trn.shape, df_tst.shape
# Out:
# ((25000, 3), (500, 3))

# %% [markdown]
# ### Get a list of unique labels (brand_id classes) from both Train/Valid and Test datasets

# %%
# keep a list of unique lables that we can use later when testing
labels = df_trn['brand_id'].unique()
labels.sort()

# Do the same for the Test (holdout) data
labels_tst = df_tst['brand_id'].unique()
labels_tst.sort()

labels.shape, labels_tst.shape
# Out:
# ((5316,), (382,))

# %% [markdown]
# ### See if any Test labels are unique to Train/Valid labels

# %%
s = set(labels)
t = set(labels_tst)
if (t.issubset(s) == False) or (s.issuperset(t) == False):
    labels_tst_unique = sorted(t.difference(s))
    print("There are " + str(len(labels_tst_unique)) + " unique labels in Test that are NOT found in Train/Valid")
else:
    print("No unique Test labels")
# Out:
# There are 66 unique labels in Test that are NOT found in Train/Valid

# %% [markdown]
# ### Display some of the Test Data which has Unique labels (not found in TRN Dataset)

# %%
pd.options.display.max_colwidth = 0
pd.options.display.html.use_mathjax = False
df_tst[df_tst['brand_id'].isin(labels_tst_unique)]
# Out:
#      brand_id  \
# 1    2727
# 14   11740
# 17   36095
# 18   1479
# 29   15467
# 48   2318
# 67   30359
# 72   19694
# 74   19734
# 80   29908
# 96   28737
# 102  16329
# 115  8917
# 139  8165
# 143  41655
# 144  7910
# 145  1568
# 177  22557
# 180  17756
# 181  12366
# 197  7141
# 198  39011
# 210  27466
# 214  34480
# 215  20963
# 217  17453
# 222  23345
# 227  1137
# 233  12347
# 238  971
# ..   ...
# 285  13559
# 288  28811
# 294  8868
# 300  4557
# 308  15957
# 312  18661
# 325  31204
# 348  15779
# 357  1028
# 360  37472
# 361  10315
# 368  14873
# 374  26285
# 376  27305
# 386  3600
# 392  24589
# 395  225
# 396  6040
# 412  29734
# 428  28713
# 429  5071
# 433  17508
# 440  4727
# 442  1393
# 461  20739
# 462  4801
# 466  28945
# 472  18414
# 473  8518
# 486  18430
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             text  \
# 1    our good friends at Johnny O Welcome you to this Episode now the iconic Johnny O clothing brand logo of the Surfer and his longboard first caught my eye several years ago, but it's a signature Johnny O style where West Coast meets East Coast prep. That truly changed the game for me, and I've been wearing Johnny O ever since. And now our listeners Khun use promo code Rich Take at checkout for 20 per cent off your first order at johnny dachau dot com. That's 20% off the regular price at johnny dachau dot com. Used the promo code Rich Take at checkout for 20 per cent off your first order.
# 14   Support for this Podcast comes from red bubble. Everyone's got a thing. Maybe you love dinosaurs or you're obsessed with doughnuts or you live and breathe super Weird. True crime shows. This is who you are, and if you want to express It, you should come to read. Bubble Read. Bubble is a marketplace with thousands of artists from around the world who are into dinosaurs, doughnuts and true crime shows to, and they sell T shirts, stickers, masks, pillows, posters and more featuring original designs that celebrate them. So you'll find stuff that you can trust will be perfect because it's the thing you love made by an artist who loves It to red bubble dot com Find your thing,
# 472  But first, a word from our sponsor, the great folks at Nets Scout. I think if you're enterprise focused, you probably have heard of Netsch out once or twice. They have a number of tools. One of the tools they'd like you to know about right now is net Scouts, Visibility without Borders. This is really good tool for people who are worried that hackers are gonna be on your network, that they've got past your defenses. And now they're at a P T and advanced, persistent threat. They're sitting in your servers looking at your files just as the hackers did. Ah, on the Starwood reservation site. For what was that? Six years Steve and hackers did For Sony Pictures Entertainment for six months. They just hang in there, cover their tracks, steal information and you're at their mercy. They can shut you down. They can exfiltrate data. Thing is, they're doing this quietly and they're pretty sophisticated. So this is where Net Scout comes in. They're smart. Data approach gives you a high resolution, consistent and continuous monitoring off all the traffic everywhere in your I V I t infrastructure in any workload. That's why they call it Visibility without Borders. Their solutions. Detect the most comprehensive array of threats and provide visibility anywhere a hacker might want to go even in the public. Cloud your public cloud, obviously, with net scouts Visibility Without Borders, you get the visibility you need to see across any network data center. Cloud Five G and more Just to ferret out the hacker that's hiding in your network, rethink the way Security is delivered for your digitally transformed business. Get a clearer view at net scout dot com Any T s c o u t I know you know Net Scout. I know you know Netscape a checkout net scout dot com for their visibility without borders two. What a cool idea. Attackers can't hide with visibility without borders. Any T s c o u t net scout dot com Steve.
# 473  Hey there. I'm Terra And I'm Jessica. And together We co host the podcast. Three Spooked Girls. If you love the paranormal or murder, join us on Mondays for full length episodes where we discuss our favorite paranormal stories And true crime. Case is and join us again on Thursdays for are Minnesota's called Stobbe Snippets where we tell you all about true crimes happening in the news. You can find us on apple podcasts, pod scene Spotify or over the hell else you listen to your pods at. You can also find us on Twitter, instagram and Facebook by using the handle at three Spooked Girls. Come and hang out with us and Get your spooky on while we scare the hell out of you.
# 486  Hey, I'm Jason Delray. I recently wrapped up the land of the Giants, the rise of Amazon. In this Podcast, we examine how Jeff Bezos turned a small online bookseller into one of the most powerful companies in the world. We start by exploring how Amazon Prime became a service with over 100 million members and the main source of the company's power. I mean, I think that's kind of what Amazon's banking on, right? That your just so locked in that you're gonna go to any other sites because, I mean, I don't on. We end this season by pondering the question. Is Amazon too big? You know, and we just don't want to be the United States of Amazon. We just really don't Land of the Giants has been recommended by the New York Times Axios wired and more. It's a candid look at the state of Amazon today how we got here and what the future might look like. Three entire first season is out Now. Find out more and binging on apple Podcast or your favorite Podcast that
#
#            id
# 1    4619134
# 14   9929340
# 17   8818521
# 18   415858
# 29   6163363
# 48   560525
# 67   7364347
# 72   5308063
# 74   5742390
# 80   7616336
# 96   7539869
# 102  5450590
# 115  9316791
# 139  4401297
# 143  9784826
# 144  6244732
# 145  510212
# 177  8080204
# 180  5016705
# 181  3374305
# 197  1848377
# 198  9218750
# 210  6687477
# 214  8196682
# 215  5627321
# 217  6249010
# 222  6390811
# 227  7614608
# 233  8351773
# 238  1570073
# ..       ...
# 285  7617514
# 288  6962045
# 294  1983090
# 300  10021557
# 308  8690715
# 312  5266853
# 325  7550442
# 348  4514626
# 357  345754
# 360  4431391
# 361  2080765
# 368  5099883
# 374  6420097
# 376  6725199
# 386  860569
# 392  6089816
# 395  144205
# 396  1787043
# 412  9400528
# 428  7028716
# 429  8839263
# 433  5585513
# 440  2036367
# 442  2425076
# 461  5855026
# 462  1205215
# 466  6947921
# 472  5239978
# 473  9965540
# 486  6982068
#
# [66 rows x 3 columns]

# %% [markdown]
# ## Begin Classification Predicition against Holdout (Test) Dataset

# %% [markdown]
# ### Load the Fully-trained TC Learner that was originally saved with the last retraining with learner.export()

# %%
learn = load_learner(PATH, 'TC_export')

# %% [markdown]
# ### Select range of rows to include from Test Dataset

# %%
R_START = 250
R_END = 500

# %% [markdown]
# ### Iterate thru Fastai's learn.predict() method for each row in selected Test Dataset

# %%
pred_lst=[]
trg_lst=df_tst.iloc[R_START:R_END]['brand_id']
for t in df_tst.iloc[R_START:R_END]['text']:
    pred = learn.predict(t)
    pred_lst.append(int(str(pred[0])))

# %% [markdown]
# ### Determine which classification predictions were correct

# %%
b = [x==y for (x,y) in zip(list(trg_lst), pred_lst)]
res_lst = ['ok' if i==True else 'XXX' for i in b]
pct = res_lst.count('ok')/len(res_lst)

# %% [markdown]
# ### Display results

# %%
d={'Target': trg_lst, 'Prediction': pred_lst, 'Result':res_lst}
pd.DataFrame(data=d)
# Out:
#     Target  Prediction Result
# 0   6876    9036        XXX
# 1   25031   1783        XXX
# 2   4481    15348       XXX
# 3   42481   42481       ok
# 4   5144    5144        ok
# 5   44      44          ok
# 6   42757   42757       ok
# 7   13650   13650       ok
# 8   42529   42529       ok
# 9   43986   43986       ok
# 10  43157   43157       ok
# 11  458     458         ok
# 12  43501   43501       ok
# 13  27847   2572        XXX
# 14  21450   21450       ok
# 15  42548   42548       ok
# 16  44290   44290       ok
# 17  174     174         ok
# 18  17855   17855       ok
# 19  36351   36351       ok

# %%
print('Accuracy: ' + str(pct))
# Out:
# Accuracy: 0.78

# %% [markdown]
# # Section Below can be used for Manual Testing
#
# ### Use below if you want to RANDOMLY choose text from the Test Dataset to classify

# %%
pd.options.display.max_colwidth = 0
pd.options.display.html.use_mathjax = False

BR_ID = np.random.choice(np.array(labels_tst),1,False)[0]
    
t = str(df_tst[df_tst['brand_id']==BR_ID].iloc[0].text)

print(BR_ID, t)
# Out:
# 28370 Hey, you guys! A Annie's Emmy nominated groundbreaking docuseries. Leah Remini. Scientology in the Aftermath returns for Season two on August 15th with 10 all new episodes. This show was riveting and revealing. I watched all of the first season and ah, second season is coming, as I mentioned August 15th on a Any Leah Remini. Scientology in the aftermath follows Leah Remini along with high level former Scientology executives and church members, as they delve deep into shocking stories of abuse, heartbreak and harassment experienced by those who have left the church and spoken publicly about their experiences. This season, Leah Remini continues her quest to give a voice to victims of the Church of Scientology. The Siri's also explores accounts of former members whose lives have been significantly impacted by the church's practice. Check it out, ladies and gentlemen, Remedy is helping people take action, turning survivors into fighters, revealing truths and seeking justice. She is relentless. Watched the first season of Leah Remini, Scientology in the aftermath, Online on demand and on The a any app and again, the new season starting season to August 15th with 10 all new episodes on Anne Leah Remini, Scientology and the Aftermath.

# %%
learn.predict(t)
# Out:
# (Category 831,
#  tensor(264),
#  tensor([8.8164e-09, 1.1244e-07, 3.7135e-06,  ..., 5.3147e-07, 9.4112e-06,
#          5.2382e-06]))

# %% [markdown]
# ### Use below if you want to choose a SPECIFIC label the Test Dataset to classify

# %%
BR_ID = 28370
t = str(df_trn[df_trn['brand_id']==BR_ID].text)
#t = str(df_tst[df_tst['brand_id']==BR_ID].text)
print(BR_ID, t)
# Out:
